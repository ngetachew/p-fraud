# %%
import pandas as pd
df = pd.read_csv("train.csv")
df
# Out:
#         UNIQUEID  DISBURSED_AMOUNT  ASSET_COST    LTV  BRANCH_ID  SUPPLIER_ID  \
# 0         420825             50578       58400  89.55         67        22807
# 1         537409             47145       65550  73.23         67        22807
# 2         417566             53278       61360  89.63         67        22807
# 3         624493             57513       66113  88.48         67        22807
# 4         539055             52378       60300  88.39         67        22807
# ...          ...               ...         ...    ...        ...          ...
# 233149    626432             63213      105405  60.72         34        20700
# 233150    606141             73651      100600  74.95         34        23775
# 233151    613658             33484       71212  48.45         77        22186
# 233152    548084             34259       73286  49.10         77        22186
# 233153    630213             75751      116009  66.81         77        22186
#
# ...

# %%
df.head(4)
# Out:
#    UNIQUEID  DISBURSED_AMOUNT  ASSET_COST    LTV  BRANCH_ID  SUPPLIER_ID  \
# 0    420825             50578       58400  89.55         67        22807
# 1    537409             47145       65550  73.23         67        22807
# 2    417566             53278       61360  89.63         67        22807
# 3    624493             57513       66113  88.48         67        22807
#
#    MANUFACTURER_ID  CURRENT_PINCODE_ID DATE_OF_BIRTH EMPLOYMENT_TYPE  ...  \
# 0               45                1441    01-01-1984        Salaried  ...
# 1               45                1502    31-07-1985   Self employed  ...
# 2               45                1497    24-08-1985   Self employed  ...
# 3               45                1501    30-12-1993   Self employed  ...
#
#   SEC_SANCTIONED_AMOUNT  SEC_DISBURSED_AMOUNT  PRIMARY_INSTAL_AMT  \
# 0                     0                     0                   0
# 1                     0                     0                1991
# ...

# %%
df.dtypes
# Out:
# UNIQUEID                                 int64
# DISBURSED_AMOUNT                         int64
# ASSET_COST                               int64
# LTV                                    float64
# BRANCH_ID                                int64
# SUPPLIER_ID                              int64
# MANUFACTURER_ID                          int64
# CURRENT_PINCODE_ID                       int64
# DATE_OF_BIRTH                           object
# EMPLOYMENT_TYPE                         object
# DISBURSAL_DATE                          object
# STATE_ID                                 int64
# EMPLOYEE_CODE_ID                         int64
# MOBILENO_AVL_FLAG                        int64
# AADHAR_FLAG                              int64
# PAN_FLAG                                 int64
# VOTERID_FLAG                             int64
# DRIVING_FLAG                             int64
# PASSPORT_FLAG                            int64
# PERFORM_CNS_SCORE                        int64
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         UNIQUEID  DISBURSED_AMOUNT  ASSET_COST    LTV  BRANCH_ID  SUPPLIER_ID  \
# 0         420825             50578       58400  89.55         67        22807
# 1         537409             47145       65550  73.23         67        22807
# 2         417566             53278       61360  89.63         67        22807
# 3         624493             57513       66113  88.48         67        22807
# 4         539055             52378       60300  88.39         67        22807
# ...          ...               ...         ...    ...        ...          ...
# 233149    626432             63213      105405  60.72         34        20700
# 233150    606141             73651      100600  74.95         34        23775
# 233151    613658             33484       71212  48.45         77        22186
# 233152    548084             34259       73286  49.10         77        22186
# 233153    630213             75751      116009  66.81         77        22186
#
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of         UNIQUEID  DISBURSED_AMOUNT  ASSET_COST    LTV  BRANCH_ID  SUPPLIER_ID  \
# 0         420825             50578       58400  89.55         67        22807
# 1         537409             47145       65550  73.23         67        22807
# 2         417566             53278       61360  89.63         67        22807
# 3         624493             57513       66113  88.48         67        22807
# 4         539055             52378       60300  88.39         67        22807
# ...          ...               ...         ...    ...        ...          ...
# 233149    626432             63213      105405  60.72         34        20700
# 233150    606141             73651      100600  74.95         34        23775
# 233151    613658             33484       71212  48.45         77        22186
# 233152    548084             34259       73286  49.10         77        22186
# 233153    630213             75751      116009  66.81         77        22186
#
# ...

# %%
xy = pd.read_csv("test.csv")
xy
# Out:
#         UNIQUEID  DISBURSED_AMOUNT  ASSET_COST    LTV  BRANCH_ID  SUPPLIER_ID  \
# 0         655269             53478       63558  86.54         67        22807
# 1         723482             55513       63163  89.45         67        22807
# 2         758529             65282       84320  79.93         78        23135
# 3         763449             46905       63896  76.58         78        17014
# 4         708663             51428       63896  86.08         78        17014
# ...          ...               ...         ...    ...        ...          ...
# 112387    755547             44875       72509  67.58         74        16646
# 112388    716994             53549       72509  78.61         74        16646
# 112389    709352             55243       72509  81.37         74        16646
# 112390    699795             55243       72509  81.37         74        16646
# 112391    755244             40274       72509  60.68         74        16646
#
# ...

# %%
data = df["BRANCH_ID"].value_counts()

# %%
print(data)
# Out:
# 2      13138
# 67     11328
# 3       9230
# 5       9218
# 36      8832
#        ...
# 217      183
# 261      176
# 84       156
# 111       89
# 158       69
# Name: BRANCH_ID, Length: 82, dtype: int64

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
print(df["STATE_ID"].value_counts())
# Out:
# 4     44870
# 3     34078
# 6     33505
# 13    17884
# 9     16022
# 8     14197
# 5     10177
# 14     9414
# 1      8936
# 7      6786
# 11     6721
# 18     5412
# 15     5049
# 12     4210
# 2      4160
# 17     3991
# 10     3605
# 16     2685
# 19     1035
# 20      185
# 21      156
# 22       76
# Name: STATE_ID, dtype: int64

# %%
print(df["LOAN_DEFAULT"].value_counts())
# Out:
# 0    182543
# 1     50611
# Name: LOAN_DEFAULT, dtype: int64
